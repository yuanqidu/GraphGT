# %%
import graphgt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
batch = 1000
x = np.random.rand(batch,1)
graphgt.plot_single_dist(x)
y_baseline = np.random.rand(batch,1)
graphgt.plot_overlap_dist(x, y_baseline)
